# %%
# env = ag , python 3.11.11

# %%
import pandas as pd
import numpy as np
import autogluon
from autogluon.tabular import TabularDataset, TabularPredictor
from sklearn.model_selection import train_test_split
from sklearn.model_selection import StratifiedKFold
import matplotlib.pyplot as plt

# %%
'''
Trained for more than 120 min
label = 'Sales'
predictor= TabularPredictor(label=label, path="AutogluonModels/" ).fit(main_train_df,  presets="best")
'''
# Out:
# '\nTrained for more than 120 min\nlabel = \'Sales\'\npredictor= TabularPredictor(label=label, path="AutogluonModels/" ).fit(main_train_df,  presets="best")\n'

# %% [markdown]
# ### Evaluation Metrics
#
# | Metric                                | Ideal Direction        | Meaning                                                                                                                                          |
# | ------------------------------------- | ---------------------- | ------------------------------------------------------------------------------------------------------------------------------------------------ |
# | **RMSE (Root Mean Squared Error)**    | ↓ lower = better       | Measures the *typical deviation* between predicted and actual values, penalizing large errors strongly. Same unit as the target (here: “Sales”). |
# | **MAE (Mean Absolute Error)**         | ↓ lower = better       | Measures the *average absolute difference* between prediction and truth. More robust to outliers than RMSE.                                      |
# | **R² (Coefficient of Determination)** | ↑ closer to 1 = better | Measures how much of the variance in your target is explained by the model (1 = perfect fit, 0 = no better than predicting the mean).            |
# | **Pearson r**                         | ↑ closer to 1 = better | Measures *linear correlation* between predicted and true values. Often very close to √R² for linear relationships.                               |

# %%
# Evaluate on all the test data takes about 16 min
# The negative values are because AutoGluon uses the same logic for regression and classification and in classification bigger is better, 
# but in regression RMSE and the errors smaller is better therefore it uses negative to sustain the logic. But we know in reality errors are like distance and are always positive.
# RMSE(Root Mean Squared Error): Off by ~524 sales units on average. Compare it to the scale of the target variable. -> Good
# MAE: Average absolute deviation — usually smaller than RMSE (good).
# R²: Excellent! Model explains about 95% of the variation in sales.
# Pearson r: Very strong correlation between predicted and true values.

# %% [markdown]
# ## Load the data

# %%
main_train_df = pd.read_csv("main_train_df.csv")
main_test_df = pd.read_csv("main_test_df.csv")

# %%
# AutoGluon only treates objects as categorical features by default and the numerical values as numerical. That is why we change the columns into categorical here.
cat_cols = [
    "Store",
    "DayOfWeek",
    "Month",
    "Year",
    "Day",
    "WeekOfYear",
    "Promo",
    "Promo2",
    "SchoolHoliday",
]

for c in cat_cols:
    main_train_df[c] = main_train_df[c].astype("category")
    main_test_df[c] = main_test_df[c].astype("category")

# %% [markdown]
# ## Train

# %%
'''
# #Trained for 5 min
# I had to disable the stacking that AutoGluon does for best quality due to the time limit.
label = 'Sales'
predictor_5min= TabularPredictor(label=label, path="AutogluonModels_5min/" ).fit(main_train_df, presets="best" , time_limit = 300 , dynamic_stacking=False)

'''
# Out:
# Warning: path already exists! This predictor may overwrite an existing predictor! path="AutogluonModels_5min/"
# Preset alias specified: 'best' maps to 'best_quality'.
# Verbosity: 2 (Standard Logging)
# =================== System Info ===================
# AutoGluon Version:  1.4.0
# Python Version:     3.11.11
# Operating System:   Darwin
# Platform Machine:   arm64
# Platform Version:   Darwin Kernel Version 23.4.0: Fri Mar 15 00:19:22 PDT 2024; root:xnu-10063.101.17~1/RELEASE_ARM64_T8112
# CPU Count:          8
# Memory Avail:       1.94 GB / 8.00 GB (24.2%)
# Disk Space Avail:   59.03 GB / 228.27 GB (25.9%)
# ===================================================
# Presets specified: ['best']
# Using hyperparameters preset: hyperparameters='zeroshot'
# Stack configuration (auto_stack=True): num_stack_levels=1, num_bag_folds=8, num_bag_sets=1
# Beginning AutoGluon training ... Time limit = 300s
# AutoGluon will save models to "/Users/sepideghorbanian/Documents/Semester_5/Research_Project/AutogluonModels_5min"
# Train Data Rows:    813764
# Train Data Columns: 18
# Label Column:       Sales
# AutoGluon infers your prediction problem is: 'regression' (because dtype of label-column == int and many unique label-values observed).
# 	Label info (max, min, mean, stddev): (41551, 0, 5774.1318, 3850.49008)
# 	If 'regression' is not the correct problem_type, please manually specify the problem_type parameter during Predictor init (You may specify problem_type as one of: ['binary', 'multiclass', 'regression', 'quantile'])
# Problem Type:       regression
# Preprocessing data ...
# Using Feature Generators to preprocess the data ...
# Fitting AutoMLPipelineFeatureGenerator...
# 	Available Memory:                    2298.34 MB
# 	Train Data (Original)  Memory Usage: 180.06 MB (7.8% of available memory)
# 	Warning: Data size prior to feature transformation consumes 7.8% of available memory. Consider increasing memory or subsampling the data to avoid instability.
# 	Inferring data type of each feature based on column values. Set feature_metadata_in to manually specify special dtypes of the features.
# 	Stage 1 Generators:
# 		Fitting AsTypeFeatureGenerator...
# 			Note: Converting 4 features to boolean dtype as they only contain 2 unique values.
# 	Stage 2 Generators:
# 		Fitting FillNaFeatureGenerator...
# 	Stage 3 Generators:
# 		Fitting IdentityFeatureGenerator...
# 		Fitting CategoryFeatureGenerator...
# 			Fitting CategoryMemoryMinimizeFeatureGenerator...
# 	Stage 4 Generators:
# 		Fitting DropUniqueFeatureGenerator...
# 	Stage 5 Generators:
# 		Fitting DropDuplicatesFeatureGenerator...
# 	Types of features in original data (raw dtype, special dtypes):
# 		('category', []) : 9 | ['Store', 'DayOfWeek', 'Promo', 'SchoolHoliday', 'Promo2', ...]
# 		('float', [])    : 5 | ['CompetitionDistance', 'CompetitionOpenSinceMonth', 'CompetitionOpenSinceYear', 'Promo2SinceWeek', 'Promo2SinceYear']
# 		('int', [])      : 1 | ['Open']
# 		('object', [])   : 3 | ['StateHoliday', 'StoreType', 'Assortment']
# 	Types of features in processed data (raw dtype, special dtypes):
# 		('category', [])  : 9 | ['Store', 'DayOfWeek', 'StateHoliday', 'StoreType', 'Assortment', ...]
# 		('float', [])     : 5 | ['CompetitionDistance', 'CompetitionOpenSinceMonth', 'CompetitionOpenSinceYear', 'Promo2SinceWeek', 'Promo2SinceYear']
# 		('int', ['bool']) : 4 | ['Open', 'Promo', 'SchoolHoliday', 'Promo2']
# 	1.7s = Fit runtime
# 	18 features in original data used to generate 18 features in processed data.
# 	Train Data (Processed) Memory Usage: 41.91 MB (1.9% of available memory)
# Data preprocessing and feature engineering runtime = 1.87s ...
# AutoGluon will gauge predictive performance using evaluation metric: 'root_mean_squared_error'
# 	This metric's sign has been flipped to adhere to being higher_is_better. The metric score can be multiplied by -1 to get the metric value.
# 	To change this, specify the eval_metric parameter of Predictor()
# Large model count detected (110 configs) ... Only displaying the first 3 models of each family. To see all, set `verbosity=3`.
# User-specified model hyperparameters to be fit:
# {
# 	'NN_TORCH': [{}, {'activation': 'elu', 'dropout_prob': 0.10077639529843717, 'hidden_size': 108, 'learning_rate': 0.002735937344002146, 'num_layers': 4, 'use_batchnorm': True, 'weight_decay': 1.356433327634438e-12, 'ag_args': {'name_suffix': '_r79', 'priority': -2}}, {'activation': 'elu', 'dropout_prob': 0.11897478034205347, 'hidden_size': 213, 'learning_rate': 0.0010474382260641949, 'num_layers': 4, 'use_batchnorm': False, 'weight_decay': 5.594471067786272e-10, 'ag_args': {'name_suffix': '_r22', 'priority': -7}}],
# 	'GBM': [{'extra_trees': True, 'ag_args': {'name_suffix': 'XT'}}, {}, {'learning_rate': 0.03, 'num_leaves': 128, 'feature_fraction': 0.9, 'min_data_in_leaf': 3, 'ag_args': {'name_suffix': 'Large', 'priority': 0, 'hyperparameter_tune_kwargs': None}}],
# 	'CAT': [{}, {'depth': 6, 'grow_policy': 'SymmetricTree', 'l2_leaf_reg': 2.1542798306067823, 'learning_rate': 0.06864209415792857, 'max_ctr_complexity': 4, 'one_hot_max_size': 10, 'ag_args': {'name_suffix': '_r177', 'priority': -1}}, {'depth': 8, 'grow_policy': 'Depthwise', 'l2_leaf_reg': 2.7997999596449104, 'learning_rate': 0.031375015734637225, 'max_ctr_complexity': 2, 'one_hot_max_size': 3, 'ag_args': {'name_suffix': '_r9', 'priority': -5}}],
# 	'XGB': [{}, {'colsample_bytree': 0.6917311125174739, 'enable_categorical': False, 'learning_rate': 0.018063876087523967, 'max_depth': 10, 'min_child_weight': 0.6028633586934382, 'ag_args': {'name_suffix': '_r33', 'priority': -8}}, {'colsample_bytree': 0.6628423832084077, 'enable_categorical': False, 'learning_rate': 0.08775715546881824, 'max_depth': 5, 'min_child_weight': 0.6294123374222513, 'ag_args': {'name_suffix': '_r89', 'priority': -16}}],
# 	'FASTAI': [{}, {'bs': 256, 'emb_drop': 0.5411770367537934, 'epochs': 43, 'layers': [800, 400], 'lr': 0.01519848858318159, 'ps': 0.23782946566604385, 'ag_args': {'name_suffix': '_r191', 'priority': -4}}, {'bs': 2048, 'emb_drop': 0.05070411322605811, 'epochs': 29, 'layers': [200, 100], 'lr': 0.08974235041576624, 'ps': 0.10393466140748028, 'ag_args': {'name_suffix': '_r102', 'priority': -11}}],
# 	'RF': [{'criterion': 'gini', 'ag_args': {'name_suffix': 'Gini', 'problem_types': ['binary', 'multiclass']}}, {'criterion': 'entropy', 'ag_args': {'name_suffix': 'Entr', 'problem_types': ['binary', 'multiclass']}}, {'criterion': 'squared_error', 'ag_args': {'name_suffix': 'MSE', 'problem_types': ['regression', 'quantile']}}],
# 	'XT': [{'criterion': 'gini', 'ag_args': {'name_suffix': 'Gini', 'problem_types': ['binary', 'multiclass']}}, {'criterion': 'entropy', 'ag_args': {'name_suffix': 'Entr', 'problem_types': ['binary', 'multiclass']}}, {'criterion': 'squared_error', 'ag_args': {'name_suffix': 'MSE', 'problem_types': ['regression', 'quantile']}}],
# }
# AutoGluon will fit 2 stack levels (L1 to L2) ...
# Fitting 106 L1 models, fit_strategy="sequential" ...
# Fitting model: LightGBMXT_BAG_L1 ... Training model for up to 198.70s of the 298.12s of remaining time.
# 	Memory not enough to fit 8 folds in parallel. Will train 4 folds in parallel instead (Estimated 13.82% memory usage per fold, 55.27%/80.00% total).
# 	Fitting 8 child models (S1F1 - S1F8) | Fitting with ParallelLocalFoldFittingStrategy (4 workers, per: cpus=2, gpus=0, memory=13.82%)
# 	-692.8053	 = Validation score   (-root_mean_squared_error)
# 	182.32s	 = Training   runtime
# 	152.84s	 = Validation runtime
# Fitting model: WeightedEnsemble_L2 ... Training model for up to 298.13s of the 93.08s of remaining time.
# 	Ensemble Weights: {'LightGBMXT_BAG_L1': 1.0}
# 	-692.8053	 = Validation score   (-root_mean_squared_error)
# 	0.01s	 = Training   runtime
# 	0.01s	 = Validation runtime
# Fitting 106 L2 models, fit_strategy="sequential" ...
# Fitting model: LightGBMXT_BAG_L2 ... Training model for up to 93.01s of the 92.98s of remaining time.
# 	Memory not enough to fit 8 folds in parallel. Will train 4 folds in parallel instead (Estimated 10.92% memory usage per fold, 43.67%/80.00% total).
# 	Fitting 8 child models (S1F1 - S1F8) | Fitting with ParallelLocalFoldFittingStrategy (4 workers, per: cpus=2, gpus=0, memory=10.92%)
# 	-660.3151	 = Validation score   (-root_mean_squared_error)
# 	83.64s	 = Training   runtime
# 	45.94s	 = Validation runtime
# Fitting model: WeightedEnsemble_L3 ... Training model for up to 298.13s of the 0.14s of remaining time.
# 	Ensemble Weights: {'LightGBMXT_BAG_L2': 0.882, 'LightGBMXT_BAG_L1': 0.118}
# 	-659.723	 = Validation score   (-root_mean_squared_error)
# 	0.41s	 = Training   runtime
# 	0.01s	 = Validation runtime
# AutoGluon training complete, total runtime = 300.35s ... Best model: WeightedEnsemble_L3 | Estimated inference throughput: 511.7 rows/s (101721 batch size)
# TabularPredictor saved. To load, use: predictor = TabularPredictor.load("/Users/sepideghorbanian/Documents/Semester_5/Research_Project/AutogluonModels_5min")

# %%
predictor_5min = TabularPredictor.load("AutogluonModels_5min/")

# %%
predictor_5min.leaderboard(silent=True)
# Out:
#                  model   score_val              eval_metric  pred_time_val  \
# 0  WeightedEnsemble_L3 -659.722987  root_mean_squared_error     198.786109
# 1    LightGBMXT_BAG_L2 -660.315067  root_mean_squared_error     198.776838
# 2    LightGBMXT_BAG_L1 -692.805336  root_mean_squared_error     152.840856
# 3  WeightedEnsemble_L2 -692.805336  root_mean_squared_error     152.854131
#
#      fit_time  pred_time_val_marginal  fit_time_marginal  stack_level  \
# 0  266.369137                0.009271           0.411764            3
# 1  265.957373               45.935982          83.642121            2
# 2  182.315252              152.840856         182.315252            1
# 3  182.327696                0.013275           0.012444            2
#
#    can_infer  fit_order
# 0       True          4
# 1       True          3
# 2       True          1
# 3       True          2

# %%
predictor_5min.evaluate(main_test_df)
# Out:
# {'root_mean_squared_error': np.float64(-649.296063833981),
#  'mean_squared_error': -421585.34375,
#  'mean_absolute_error': -400.3708801269531,
#  'r2': 0.9715232849121094,
#  'pearsonr': 0.9856672791669061,
#  'median_absolute_error': -268.4130859375}

# %% [markdown]
# ## Test

# %%
# test - the big and small test data are the same in distribution and size

small_df = main_test_df.sample(frac=0.01, random_state=42)
big_df = main_test_df.sample(frac=0.2, random_state=42)

# %%
eval_small_df_5min = predictor_5min.evaluate(small_df)
eval_small_df_5min
# Out:
# {'root_mean_squared_error': np.float64(-700.327066569659),
#  'mean_squared_error': -490458.0625,
#  'mean_absolute_error': -426.9862976074219,
#  'r2': 0.9662561416625977,
#  'pearsonr': 0.9829947046375225,
#  'median_absolute_error': -287.005859375}

# %%
eval_big_df_5min = predictor_5min.evaluate(big_df)
eval_big_df_5min
# Out:
# {'root_mean_squared_error': np.float64(-643.4608506729847),
#  'mean_squared_error': -414041.875,
#  'mean_absolute_error': -401.2595520019531,
#  'r2': 0.9723244905471802,
#  'pearsonr': 0.9860701837697425,
#  'median_absolute_error': -267.95751953125}

# %%
# test - the big and small test data are different in distribution and size
big_df = main_test_df.sample(frac=0.4, random_state=42)
small_df = main_test_df[
    (main_test_df['StoreType'] == 'c') &  # specific store type
    (main_test_df['Month'].isin([1,2]))   # specific months
].sample(frac=0.1, random_state=42)

# %%
eval_small_df_5min = predictor_5min.evaluate(small_df)
eval_small_df_5min
# Out:
# {'root_mean_squared_error': np.float64(-807.7890524195691),
#  'mean_squared_error': -652523.125,
#  'mean_absolute_error': -438.90081787109375,
#  'r2': 0.9480795860290527,
#  'pearsonr': 0.974525900393623,
#  'median_absolute_error': -292.4287109375}

# %%
eval_big_df_5min = predictor_5min.evaluate(big_df)
eval_big_df_5min
# Out:
# {'root_mean_squared_error': np.float64(-646.2191308713576),
#  'mean_squared_error': -417599.15625,
#  'mean_absolute_error': -400.75775146484375,
#  'r2': 0.9719414710998535,
#  'pearsonr': 0.9858810908962864,
#  'median_absolute_error': -268.5272216796875}

# %%
small_df["Sales"].describe()
# Out:
# count      531.000000
# mean      5575.570621
# std       3548.445508
# min          0.000000
# 25%       3814.000000
# 50%       5635.000000
# 75%       7517.500000
# max      20645.000000
# Name: Sales, dtype: float64

# %%
big_df["Sales"].describe()
# Out:
# count    81378.000000
# mean      5764.689412
# std       3857.893080
# min          0.000000
# 25%       3707.000000
# 50%       5733.000000
# 75%       7852.000000
# max      38722.000000
# Name: Sales, dtype: float64

# %%
small_df_label = small_df["Sales"]
small_df.drop("Sales" , axis = 1)
pred_small_5min = predictor_5min.predict(small_df)
pred_small_5min
# Out:
# 38993     4328.358398
# 149261    7571.376465
# 100353    8137.081543
# 69076     5896.909180
# 61474     4759.713379
#              ...
# 40377     5805.443848
# 144060    6293.888672
# 67787       25.234823
# 154990    6133.780273
# 22885     9202.931641
# Name: Sales, Length: 531, dtype: float32

# %%
plt.scatter(small_df_label, pred_small_5min, alpha=0.5)
plt.xlabel("Actual Sales")
plt.ylabel("Predicted Sales")
plt.title("Predicted vs Actual Sales")
plt.show()

# %%
big_df_label = big_df["Sales"]
big_df.drop("Sales" , axis = 1)
pred_big_5min = predictor_5min.predict(big_df)
pred_big_5min
# Out:
# 138619    6698.904785
# 39765     5922.348145
# 173119    8247.121094
# 53208       27.661917
# 142984       9.964546
#              ...
# 158769    3821.330566
# 23008     8745.782227
# 189557    6552.892578
# 125550    4218.829590
# 169805    3483.090576
# Name: Sales, Length: 81378, dtype: float32

# %%
plt.scatter(big_df_label, pred_big_5min, alpha=0.5)
plt.xlabel("Actual Sales")
plt.ylabel("Predicted Sales")
plt.title("Predicted vs Actual Sales")
plt.show()

# %%
# The results still seem to be good!!!
# It seems like the 5 min trained model is performing worse in the small dataset comparing to the big dataset. the errors (RMSE) are slightly different(709, 679).
# The model works slightly better on the big dataset comparing to the small dataset. However it is not enough.

# %% [markdown]
# ## Non-Startified

# %%
data = main_train_df
data
# Out:
#        Store DayOfWeek  Open Promo StateHoliday SchoolHoliday StoreType  \
# 0         44         2     1     1            0             0         a
# 1        346         2     1     1            0             1         a
# 2        331         7     0     0            0             0         a
# 3        572         7     0     0            0             0         d
# 4       1014         3     1     1            0             1         a
# ...      ...       ...   ...   ...          ...           ...       ...
# 813759   932         6     1     0            0             0         a
# 813760    25         2     1     0            0             0         c
# 813761   135         2     1     1            0             1         d
# 813762   923         4     1     0            0             0         a
# 813763   249         6     1     0            0             0         d
#
#        Assortment  CompetitionDistance  CompetitionOpenSinceMonth  \
# 0               a                540.0                        6.0
# 1               c               8090.0                        NaN
# 2               c                670.0                        NaN
# 3               c               9230.0                        4.0
# 4               c                210.0                        NaN
# ...           ...                  ...                        ...
# 813759          a              15700.0                        NaN
# 813760          a                430.0                        4.0
# 813761          a               5190.0                        NaN
# 813762          a                280.0                        9.0
# 813763          c              18010.0                        9.0
#
#         CompetitionOpenSinceYear Promo2  Promo2SinceWeek  Promo2SinceYear  \
# 0                         2011.0      0              NaN              NaN
# 1                            NaN      0              NaN              NaN
# 2                            NaN      1             14.0           2015.0
# 3                         2004.0      1             37.0           2009.0
# 4                            NaN      1             31.0           2013.0
# ...                          ...    ...              ...              ...
# 813759                       NaN      1             13.0           2010.0
# 813760                    2003.0      0              NaN              NaN
# 813761                       NaN      1              1.0           2013.0
# 813762                    2008.0      0              NaN              NaN
# 813763                    2014.0      0              NaN              NaN
#
#         Year Month Day WeekOfYear  Sales
# 0       2014     5   6         19   7076
# 1       2014     7  29         31   8129
# 2       2014     9  28         39      0
# 3       2013    11  17         46      0
# 4       2015     7  15         29  12288
# ...      ...   ...  ..        ...    ...
# 813759  2013    10   5         40   4994
# 813760  2013     5   7         19  13145
# 813761  2015     3  31         14   9776
# 813762  2015     3  12         11   4790
# 813763  2013     2   9          6   4343
#
# [813764 rows x 19 columns]

# %%
n_splits = 5

split_size = len(data) // n_splits

data_shuffled = data.sample(frac=1, random_state=42).reset_index(drop=True)

datasets = []
for i in range(n_splits):
    start_idx = i * split_size
    end_idx = (i + 1) * split_size if i < n_splits - 1 else len(data_shuffled)
    datasets.append(data_shuffled.iloc[start_idx:end_idx].reset_index(drop=True))

# %%
datasets[0]
# Out:
#        Store DayOfWeek  Open Promo StateHoliday SchoolHoliday StoreType  \
# 0        622         5     1     1            0             1         a
# 1        569         5     1     0            0             0         a
# 2       1026         5     1     1            0             1         c
# 3        672         3     1     0            0             0         c
# 4        764         3     1     0            0             0         a
# ...      ...       ...   ...   ...          ...           ...       ...
# 162747   714         6     1     0            0             0         d
# 162748   941         1     1     1            0             0         a
# 162749     3         1     1     0            0             1         a
# 162750   537         4     0     1            a             0         a
# 162751   212         2     1     1            0             0         a
#
#        Assortment  CompetitionDistance  CompetitionOpenSinceMonth  \
# 0               c                  NaN                        NaN
# 1               a               1340.0                        9.0
# 2               a                450.0                        6.0
# 3               a                240.0                        9.0
# 4               c              26490.0                        NaN
# ...           ...                  ...                        ...
# 162747          c              12070.0                       10.0
# 162748          a               1200.0                       12.0
# 162749          a              14130.0                       12.0
# 162750          a                600.0                        5.0
# 162751          c              15050.0                        9.0
#
#         CompetitionOpenSinceYear Promo2  Promo2SinceWeek  Promo2SinceYear  \
# 0                            NaN      0              NaN              NaN
# 1                         2006.0      0              NaN              NaN
# 2                         2011.0      1             48.0           2012.0
# 3                         2002.0      0              NaN              NaN
# 4                            NaN      1             10.0           2014.0
# ...                          ...    ...              ...              ...
# 162747                    2005.0      1             10.0           2013.0
# 162748                    2011.0      1             31.0           2013.0
# 162749                    2006.0      1             14.0           2011.0
# 162750                    2002.0      1              1.0           2012.0
# 162751                    2008.0      0              NaN              NaN
#
#         Year Month Day WeekOfYear  Sales
# 0       2013     7   5         27   5122
# 1       2014     2  14          7   4891
# 2       2014     8   1         31  10598
# 3       2013    10  16         42   7345
# 4       2013     2  27          9   1934
# ...      ...   ...  ..        ...    ...
# 162747  2014     7  19         29   4181
# 162748  2013    11  18         47   6803
# 162749  2013     7  22         30   5152
# 162750  2014     5   1         18      0
# 162751  2014     3  18         12   5031
#
# [162752 rows x 19 columns]

# %%
splits = {}

for i, ds in enumerate(datasets):
    train, test = train_test_split(ds, test_size=0.2, random_state=42)  
    splits[f'dataset_{i+1}'] = {'train': train.reset_index(drop=True),
                                 'test': test.reset_index(drop=True)}

# %%
X_train_1, X_test_1 = splits['dataset_1']['train'] , splits['dataset_1']['test'] 
X_train_2, X_test_2 = splits['dataset_2']['train'] , splits['dataset_2']['test'] 
X_train_3, X_test_3= splits['dataset_3']['train'] , splits['dataset_3']['test'] 
X_train_4, X_test_4= splits['dataset_4']['train'] , splits['dataset_4']['test'] 
X_train_5, X_test_5= splits['dataset_5']['train'] , splits['dataset_5']['test']

# %%
X_main_train = pd.concat([X_train_1, X_train_2, X_train_3, X_train_4 , X_train_5]).reset_index(drop=True)
X_main_test = pd.concat([X_test_1, X_test_2, X_test_3, X_test_4, X_test_5]).reset_index(drop=True)

# %%
label = 'Sales'
predictor_5min_non= TabularPredictor(label=label, path="AutogluonModels_5min_non/" ).fit(X_main_train,  presets="best" , time_limit = 300 , dynamic_stacking=False)
# Out:
# Warning: path already exists! This predictor may overwrite an existing predictor! path="AutogluonModels_5min_non/"
# Preset alias specified: 'best' maps to 'best_quality'.
# Verbosity: 2 (Standard Logging)
# =================== System Info ===================
# AutoGluon Version:  1.4.0
# Python Version:     3.11.11
# Operating System:   Darwin
# Platform Machine:   arm64
# Platform Version:   Darwin Kernel Version 23.4.0: Fri Mar 15 00:19:22 PDT 2024; root:xnu-10063.101.17~1/RELEASE_ARM64_T8112
# CPU Count:          8
# Memory Avail:       2.13 GB / 8.00 GB (26.6%)
# Disk Space Avail:   59.11 GB / 228.27 GB (25.9%)
# ===================================================
# Presets specified: ['best']
# Using hyperparameters preset: hyperparameters='zeroshot'
# Stack configuration (auto_stack=True): num_stack_levels=1, num_bag_folds=8, num_bag_sets=1
# Beginning AutoGluon training ... Time limit = 300s
# AutoGluon will save models to "/Users/sepideghorbanian/Documents/Semester_5/Research_Project/AutogluonModels_5min_non"
# Train Data Rows:    651008
# Train Data Columns: 18
# Label Column:       Sales
# AutoGluon infers your prediction problem is: 'regression' (because dtype of label-column == int and many unique label-values observed).
# 	Label info (max, min, mean, stddev): (41551, 0, 5774.58875, 3851.73577)
# 	If 'regression' is not the correct problem_type, please manually specify the problem_type parameter during Predictor init (You may specify problem_type as one of: ['binary', 'multiclass', 'regression', 'quantile'])
# Problem Type:       regression
# Preprocessing data ...
# Using Feature Generators to preprocess the data ...
# Fitting AutoMLPipelineFeatureGenerator...
# 	Available Memory:                    2271.42 MB
# 	Train Data (Original)  Memory Usage: 144.05 MB (6.3% of available memory)
# 	Warning: Data size prior to feature transformation consumes 6.3% of available memory. Consider increasing memory or subsampling the data to avoid instability.
# 	Inferring data type of each feature based on column values. Set feature_metadata_in to manually specify special dtypes of the features.
# 	Stage 1 Generators:
# 		Fitting AsTypeFeatureGenerator...
# 			Note: Converting 4 features to boolean dtype as they only contain 2 unique values.
# 	Stage 2 Generators:
# 		Fitting FillNaFeatureGenerator...
# 	Stage 3 Generators:
# 		Fitting IdentityFeatureGenerator...
# 		Fitting CategoryFeatureGenerator...
# 			Fitting CategoryMemoryMinimizeFeatureGenerator...
# 	Stage 4 Generators:
# 		Fitting DropUniqueFeatureGenerator...
# 	Stage 5 Generators:
# 		Fitting DropDuplicatesFeatureGenerator...
# 	Types of features in original data (raw dtype, special dtypes):
# 		('category', []) : 9 | ['Store', 'DayOfWeek', 'Promo', 'SchoolHoliday', 'Promo2', ...]
# 		('float', [])    : 5 | ['CompetitionDistance', 'CompetitionOpenSinceMonth', 'CompetitionOpenSinceYear', 'Promo2SinceWeek', 'Promo2SinceYear']
# 		('int', [])      : 1 | ['Open']
# 		('object', [])   : 3 | ['StateHoliday', 'StoreType', 'Assortment']
# 	Types of features in processed data (raw dtype, special dtypes):
# 		('category', [])  : 9 | ['Store', 'DayOfWeek', 'StateHoliday', 'StoreType', 'Assortment', ...]
# 		('float', [])     : 5 | ['CompetitionDistance', 'CompetitionOpenSinceMonth', 'CompetitionOpenSinceYear', 'Promo2SinceWeek', 'Promo2SinceYear']
# 		('int', ['bool']) : 4 | ['Open', 'Promo', 'SchoolHoliday', 'Promo2']
# 	1.4s = Fit runtime
# 	18 features in original data used to generate 18 features in processed data.
# 	Train Data (Processed) Memory Usage: 33.53 MB (1.5% of available memory)
# Data preprocessing and feature engineering runtime = 1.54s ...
# AutoGluon will gauge predictive performance using evaluation metric: 'root_mean_squared_error'
# 	This metric's sign has been flipped to adhere to being higher_is_better. The metric score can be multiplied by -1 to get the metric value.
# 	To change this, specify the eval_metric parameter of Predictor()
# Large model count detected (110 configs) ... Only displaying the first 3 models of each family. To see all, set `verbosity=3`.
# User-specified model hyperparameters to be fit:
# {
# 	'NN_TORCH': [{}, {'activation': 'elu', 'dropout_prob': 0.10077639529843717, 'hidden_size': 108, 'learning_rate': 0.002735937344002146, 'num_layers': 4, 'use_batchnorm': True, 'weight_decay': 1.356433327634438e-12, 'ag_args': {'name_suffix': '_r79', 'priority': -2}}, {'activation': 'elu', 'dropout_prob': 0.11897478034205347, 'hidden_size': 213, 'learning_rate': 0.0010474382260641949, 'num_layers': 4, 'use_batchnorm': False, 'weight_decay': 5.594471067786272e-10, 'ag_args': {'name_suffix': '_r22', 'priority': -7}}],
# 	'GBM': [{'extra_trees': True, 'ag_args': {'name_suffix': 'XT'}}, {}, {'learning_rate': 0.03, 'num_leaves': 128, 'feature_fraction': 0.9, 'min_data_in_leaf': 3, 'ag_args': {'name_suffix': 'Large', 'priority': 0, 'hyperparameter_tune_kwargs': None}}],
# 	'CAT': [{}, {'depth': 6, 'grow_policy': 'SymmetricTree', 'l2_leaf_reg': 2.1542798306067823, 'learning_rate': 0.06864209415792857, 'max_ctr_complexity': 4, 'one_hot_max_size': 10, 'ag_args': {'name_suffix': '_r177', 'priority': -1}}, {'depth': 8, 'grow_policy': 'Depthwise', 'l2_leaf_reg': 2.7997999596449104, 'learning_rate': 0.031375015734637225, 'max_ctr_complexity': 2, 'one_hot_max_size': 3, 'ag_args': {'name_suffix': '_r9', 'priority': -5}}],
# 	'XGB': [{}, {'colsample_bytree': 0.6917311125174739, 'enable_categorical': False, 'learning_rate': 0.018063876087523967, 'max_depth': 10, 'min_child_weight': 0.6028633586934382, 'ag_args': {'name_suffix': '_r33', 'priority': -8}}, {'colsample_bytree': 0.6628423832084077, 'enable_categorical': False, 'learning_rate': 0.08775715546881824, 'max_depth': 5, 'min_child_weight': 0.6294123374222513, 'ag_args': {'name_suffix': '_r89', 'priority': -16}}],
# 	'FASTAI': [{}, {'bs': 256, 'emb_drop': 0.5411770367537934, 'epochs': 43, 'layers': [800, 400], 'lr': 0.01519848858318159, 'ps': 0.23782946566604385, 'ag_args': {'name_suffix': '_r191', 'priority': -4}}, {'bs': 2048, 'emb_drop': 0.05070411322605811, 'epochs': 29, 'layers': [200, 100], 'lr': 0.08974235041576624, 'ps': 0.10393466140748028, 'ag_args': {'name_suffix': '_r102', 'priority': -11}}],
# 	'RF': [{'criterion': 'gini', 'ag_args': {'name_suffix': 'Gini', 'problem_types': ['binary', 'multiclass']}}, {'criterion': 'entropy', 'ag_args': {'name_suffix': 'Entr', 'problem_types': ['binary', 'multiclass']}}, {'criterion': 'squared_error', 'ag_args': {'name_suffix': 'MSE', 'problem_types': ['regression', 'quantile']}}],
# 	'XT': [{'criterion': 'gini', 'ag_args': {'name_suffix': 'Gini', 'problem_types': ['binary', 'multiclass']}}, {'criterion': 'entropy', 'ag_args': {'name_suffix': 'Entr', 'problem_types': ['binary', 'multiclass']}}, {'criterion': 'squared_error', 'ag_args': {'name_suffix': 'MSE', 'problem_types': ['regression', 'quantile']}}],
# }
# AutoGluon will fit 2 stack levels (L1 to L2) ...
# Fitting 106 L1 models, fit_strategy="sequential" ...
# Fitting model: LightGBMXT_BAG_L1 ... Training model for up to 198.92s of the 298.45s of remaining time.
# 	Memory not enough to fit 8 folds in parallel. Will train 4 folds in parallel instead (Estimated 10.81% memory usage per fold, 43.26%/80.00% total).
# 	Fitting 8 child models (S1F1 - S1F8) | Fitting with ParallelLocalFoldFittingStrategy (4 workers, per: cpus=2, gpus=0, memory=10.81%)
# 	-693.5181	 = Validation score   (-root_mean_squared_error)
# 	189.03s	 = Training   runtime
# 	188.46s	 = Validation runtime
# Fitting model: WeightedEnsemble_L2 ... Training model for up to 298.46s of the 83.48s of remaining time.
# 	Ensemble Weights: {'LightGBMXT_BAG_L1': 1.0}
# 	-693.5181	 = Validation score   (-root_mean_squared_error)
# 	0.01s	 = Training   runtime
# 	0.02s	 = Validation runtime
# Fitting 106 L2 models, fit_strategy="sequential" ...
# Fitting model: LightGBMXT_BAG_L2 ... Training model for up to 83.40s of the 83.36s of remaining time.
# 	Memory not enough to fit 8 folds in parallel. Will train 4 folds in parallel instead (Estimated 11.75% memory usage per fold, 46.99%/80.00% total).
# 	Fitting 8 child models (S1F1 - S1F8) | Fitting with ParallelLocalFoldFittingStrategy (4 workers, per: cpus=2, gpus=0, memory=11.75%)
# 	-664.3766	 = Validation score   (-root_mean_squared_error)
# 	77.11s	 = Training   runtime
# 	45.64s	 = Validation runtime
# Fitting model: WeightedEnsemble_L3 ... Training model for up to 298.46s of the -2.33s of remaining time.
# 	Ensemble Weights: {'LightGBMXT_BAG_L2': 0.85, 'LightGBMXT_BAG_L1': 0.15}
# 	-663.3976	 = Validation score   (-root_mean_squared_error)
# 	0.26s	 = Training   runtime
# 	0.01s	 = Validation runtime
# AutoGluon training complete, total runtime = 302.66s ... Best model: WeightedEnsemble_L3 | Estimated inference throughput: 347.6 rows/s (81376 batch size)
# TabularPredictor saved. To load, use: predictor = TabularPredictor.load("/Users/sepideghorbanian/Documents/Semester_5/Research_Project/AutogluonModels_5min_non")

# %%
preds = predictor_5min_non.evaluate(X_main_test)
preds
# Out:
# {'root_mean_squared_error': np.float64(-632.4313048380722),
#  'mean_squared_error': -399969.34375,
#  'mean_absolute_error': -400.39544677734375,
#  'r2': 0.9729529023170471,
#  'pearsonr': 0.9863927658416468,
#  'median_absolute_error': -269.7724609375}

# %%
X_main_test["Sales"].describe()
# Out:
# count    162756.000000
# mean       5772.304081
# std        3845.514682
# min           0.000000
# 25%        3724.000000
# 50%        5745.000000
# 75%        7846.000000
# max       37646.000000
# Name: Sales, dtype: float64

# %%
small_df = pd.concat([X_test_1[100:150] ,X_test_2[100:150] ,X_test_3[100:150] ,X_test_4[100:150] , X_test_5[100:150]])
preds_small_df = predictor_5min_non.evaluate(small_df)
preds_small_df
# Out:
# {'root_mean_squared_error': np.float64(-676.4299590359735),
#  'mean_squared_error': -457557.5,
#  'mean_absolute_error': -420.87725830078125,
#  'r2': 0.973990797996521,
#  'pearsonr': 0.9871874147458171,
#  'median_absolute_error': -264.612548828125}

# %%
small_df["Sales"].describe()
# Out:
# count      250.000000
# mean      5855.560000
# std       4202.711934
# min          0.000000
# 25%       3623.750000
# 50%       5668.500000
# 75%       7782.000000
# max      22673.000000
# Name: Sales, dtype: float64

# %% [markdown]
# I think the problem is the data is too incomplex. Also we do the startification which makes all the datsets have almost the same distribution, although the small data is sampeled randomly from the test data but it still migh have the familier patterns. The model learns well and can perform good on both small and big dataset. We still get slightly better evaluation on big datasets but it is not that much.
# I turn some of the features into categorical and retrained the model which improved the perforcmance significantly, (MAE from 700 to 400).
# the model has been trained on the main training data. Then we made 2 datasets from the test data, the big one is with the same normal distribution, and the smaller one is picked with a different and specific distribution to be different. We see that the model performs worse on the smaller one.
# We also try with 2 subsets of the test data  which are only different in size, the big and small. The results for the big dataset is bigger but there is not too much of a difference.
